# %% [markdown]
# build a encoder-decoder model order input from least to greastest.  first step just return the indices of fixed lenght input, second step variable lenght input, embedding layer and pointer network.
#
# Note that sequences are of fixed lenght

# %%
import numpy as np
import tensorflow as tf
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# Global config variables
num_steps = 4 
batch_size = 16
state_size = 12
learning_rate = 0.1

# %%
def gen_data(time_steps=4, batch_size=16, num_batches=4000):
    X = np.random.rand(num_batches * batch_size, time_steps)
    Y = np.asarray([np.argsort(e) for e in X])
    for i in range(num_batches):
        _x = X[i * batch_size:(i + 1) * batch_size]
        _y = Y[i * batch_size:(i + 1) * batch_size]
        yield _x, _y

# %%
"""
Placeholders
"""

x = tf.placeholder(tf.float32, [batch_size, num_steps], name='input_placeholder')
y = tf.placeholder(tf.int32, [batch_size, num_steps], name='labels_placeholder')
init_state = tf.zeros([batch_size, state_size])

"""
RNN Inputs
"""

# Turn our x placeholder into a list of one-hot tensors:
# rnn_inputs is a list of num_steps tensors with shape [batch_size, num_classes]
rnn_inputs = tf.expand_dims(x, 2)
rnn_inputs = tf.unstack(rnn_inputs, axis=1)

# %%
rnn_inputs
# Out:
# [<tf.Tensor 'unstack:0' shape=(16, 1) dtype=float32>,
#  <tf.Tensor 'unstack:1' shape=(16, 1) dtype=float32>,
#  <tf.Tensor 'unstack:2' shape=(16, 1) dtype=float32>,
#  <tf.Tensor 'unstack:3' shape=(16, 1) dtype=float32>]

# %%
with tf.variable_scope('rnn_cell'):
    W = tf.get_variable('W', [1 + state_size, state_size])
    b = tf.get_variable('b', [state_size], initializer=tf.constant_initializer(0.0))

def rnn_cell(rnn_input, state):
     print rnn_input
     print state
     return tf.tanh(tf.matmul(tf.concat([rnn_input, state], 1), W) + b)

# %%
state = init_state
rnn_outputs = []
for rnn_input in rnn_inputs:
    state = rnn_cell(rnn_input, state)
    rnn_outputs.append(state)
final_state = rnn_outputs[-1]
# Out:
# Tensor("unstack:0", shape=(16, 1), dtype=float32)
# Tensor("zeros:0", shape=(16, 12), dtype=float32)
# Tensor("unstack:1", shape=(16, 1), dtype=float32)
# Tensor("Tanh:0", shape=(16, 12), dtype=float32)
# Tensor("unstack:2", shape=(16, 1), dtype=float32)
# Tensor("Tanh_1:0", shape=(16, 12), dtype=float32)
# Tensor("unstack:3", shape=(16, 1), dtype=float32)
# Tensor("Tanh_2:0", shape=(16, 12), dtype=float32)

# %%
#decoder cell
with tf.variable_scope('decoder_cell'):
    W = tf.get_variable('W', [1 + state_size, state_size])
    b = tf.get_variable('b', [state_size], initializer=tf.constant_initializer(0.0))

def rnn_cell(rnn_input, state):
     return tf.tanh(tf.matmul(tf.concat([rnn_input, state], 1), W) + b)

# %%
state = final_state
decoder_outputs = []
for rnn_input in rnn_inputs:
    state = rnn_cell(rnn_input, state)
    rnn_outputs.append(state)
final_state = rnn_outputs[-1]

# %%
num_classes = num_steps
with tf.variable_scope('softmax'):
    W = tf.get_variable('W', [state_size, num_classes])
    b = tf.get_variable('b', [num_classes], initializer=tf.constant_initializer(0.0))
logits = [tf.matmul(rnn_output, W) + b for rnn_output in rnn_outputs]
predictions = [tf.nn.softmax(logit) for logit in logits]

# %%
y_as_list = tf.unstack(y, num=num_steps, axis=1)

#losses and train_step
losses = [tf.nn.sparse_softmax_cross_entropy_with_logits(labels=label, logits=logit) for \
          logit, label in zip(logits, y_as_list)]
total_loss = tf.reduce_mean(losses)
train_step = tf.train.AdagradOptimizer(learning_rate).minimize(total_loss)

# %%
def train_network(num_epochs, num_steps, state_size, verbose=True):
    with tf.Session() as sess:
        sess.run(tf.global_variables_initializer())
        training_losses = []
        for i in range(num_epochs):
            training_loss = 0

            if verbose:
                print("\nEPOCH", i)
            d = gen_data(time_steps=4, batch_size=16, num_batches=4000)
            for j in range(4000):
                X,Y = d.next()
                training_state = np.zeros((batch_size, state_size))
                tr_losses, training_loss_, training_state, _, preds_ = \
                    sess.run([losses,
                              total_loss,
                              final_state,
                              train_step,
                              predictions],
                                  feed_dict={x:X, y:Y, init_state:training_state})
                training_loss += training_loss_

                if j % 40 == 0 and j > 0:
                    if verbose:
                        print("Average loss at step", j,
                              "for last 250 steps:", training_loss / 100)
                    training_losses.append(training_loss / 100)
                    training_loss = 0

    return training_losses

# %%
training_losses = train_network(10,num_steps, state_size)
plt.plot(training_losses)
# Out:
# ('\nEPOCH', 0)
# ('Average loss at step', 40, 'for last 250 steps:', 0.5562443542480469)
# ('Average loss at step', 80, 'for last 250 steps:', 0.5221774351596832)
# ('Average loss at step', 120, 'for last 250 steps:', 0.5095674908161163)
# ('Average loss at step', 160, 'for last 250 steps:', 0.5043389344215393)
# ('Average loss at step', 200, 'for last 250 steps:', 0.49402886390686035)
# ('Average loss at step', 240, 'for last 250 steps:', 0.49760870218276976)
# ('Average loss at step', 280, 'for last 250 steps:', 0.49203634142875674)
# ('Average loss at step', 320, 'for last 250 steps:', 0.49661150336265564)
# ('Average loss at step', 360, 'for last 250 steps:', 0.4890198564529419)
# ('Average loss at step', 400, 'for last 250 steps:', 0.4942000770568848)
# ('Average loss at step', 440, 'for last 250 steps:', 0.4842912435531616)
# ('Average loss at step', 480, 'for last 250 steps:', 0.4893732690811157)
# ('Average loss at step', 520, 'for last 250 steps:', 0.47907828688621523)
# ('Average loss at step', 560, 'for last 250 steps:', 0.478260635137558)
# ('Average loss at step', 600, 'for last 250 steps:', 0.46980547785758975)
# ('Average loss at step', 640, 'for last 250 steps:', 0.4683757543563843)
# ('Average loss at step', 680, 'for last 250 steps:', 0.4592124843597412)
# ('Average loss at step', 720, 'for last 250 steps:', 0.4642903530597687)
# ('Average loss at step', 760, 'for last 250 steps:', 0.45913902759552)
# ('Average loss at step', 800, 'for last 250 steps:', 0.4510199725627899)
# ('Average loss at step', 840, 'for last 250 steps:', 0.4585440409183502)
# ('Average loss at step', 880, 'for last 250 steps:', 0.453800163269043)
# ('Average loss at step', 920, 'for last 250 steps:', 0.45057108283042907)
# ('Average loss at step', 960, 'for last 250 steps:', 0.4515780031681061)
# ('Average loss at step', 1000, 'for last 250 steps:', 0.44808650851249693)
# ('Average loss at step', 1040, 'for last 250 steps:', 0.44861532032489776)
# ('Average loss at step', 1080, 'for last 250 steps:', 0.4425161051750183)
# ('Average loss at step', 1120, 'for last 250 steps:', 0.4433172595500946)
# ('Average loss at step', 1160, 'for last 250 steps:', 0.4411105537414551)
# ('Average loss at step', 1200, 'for last 250 steps:', 0.4407069158554077)
# ('Average loss at step', 1240, 'for last 250 steps:', 0.44030303359031675)
# ('Average loss at step', 1280, 'for last 250 steps:', 0.4344891059398651)
# ('Average loss at step', 1320, 'for last 250 steps:', 0.4299024212360382)
# ('Average loss at step', 1360, 'for last 250 steps:', 0.43035137295722964)
# ('Average loss at step', 1400, 'for last 250 steps:', 0.4324099564552307)
# ('Average loss at step', 1440, 'for last 250 steps:', 0.43041616678237915)
# ('Average loss at step', 1480, 'for last 250 steps:', 0.42367553770542143)
# ('Average loss at step', 1520, 'for last 250 steps:', 0.4231301271915436)
# ('Average loss at step', 1560, 'for last 250 steps:', 0.42962069511413575)
# ('Average loss at step', 1600, 'for last 250 steps:', 0.42358105540275576)
# ('Average loss at step', 1640, 'for last 250 steps:', 0.4247362267971039)
# ('Average loss at step', 1680, 'for last 250 steps:', 0.423671253323555)
# ('Average loss at step', 1720, 'for last 250 steps:', 0.42606251180171967)
# ('Average loss at step', 1760, 'for last 250 steps:', 0.4203255307674408)
# ('Average loss at step', 1800, 'for last 250 steps:', 0.4172797977924347)
# ('Average loss at step', 1840, 'for last 250 steps:', 0.42556092619895936)
# ('Average loss at step', 1880, 'for last 250 steps:', 0.42076861560344697)
# ('Average loss at step', 1920, 'for last 250 steps:', 0.4178918713331223)
# ('Average loss at step', 1960, 'for last 250 steps:', 0.4193025630712509)
# ('Average loss at step', 2000, 'for last 250 steps:', 0.4175515103340149)
# ('Average loss at step', 2040, 'for last 250 steps:', 0.4180022835731506)
# ('Average loss at step', 2080, 'for last 250 steps:', 0.40998242020606995)
# ('Average loss at step', 2120, 'for last 250 steps:', 0.41130765080451964)
# ('Average loss at step', 2160, 'for last 250 steps:', 0.4148506373167038)
# ('Average loss at step', 2200, 'for last 250 steps:', 0.4076860976219177)
# ('Average loss at step', 2240, 'for last 250 steps:', 0.4204933601617813)
# ('Average loss at step', 2280, 'for last 250 steps:', 0.4084398859739304)
# ('Average loss at step', 2320, 'for last 250 steps:', 0.4067471414804459)
# ('Average loss at step', 2360, 'for last 250 steps:', 0.41123257756233217)
# ('Average loss at step', 2400, 'for last 250 steps:', 0.4017763316631317)
# ('Average loss at step', 2440, 'for last 250 steps:', 0.4073833310604095)
# ('Average loss at step', 2480, 'for last 250 steps:', 0.40943100333213805)
# ('Average loss at step', 2520, 'for last 250 steps:', 0.40439573347568514)
# ('Average loss at step', 2560, 'for last 250 steps:', 0.4019214195013046)
# ('Average loss at step', 2600, 'for last 250 steps:', 0.3991984170675278)
# ('Average loss at step', 2640, 'for last 250 steps:', 0.4079176616668701)
# ('Average loss at step', 2680, 'for last 250 steps:', 0.40429078340530394)
# ('Average loss at step', 2720, 'for last 250 steps:', 0.39743554174900053)
# ('Average loss at step', 2760, 'for last 250 steps:', 0.40150782763957976)
# ('Average loss at step', 2800, 'for last 250 steps:', 0.3997639799118042)
# ('Average loss at step', 2840, 'for last 250 steps:', 0.4002140325307846)
# ('Average loss at step', 2880, 'for last 250 steps:', 0.400445356965065)
# ('Average loss at step', 2920, 'for last 250 steps:', 0.397046702504158)
# ('Average loss at step', 2960, 'for last 250 steps:', 0.39223228335380556)
# ('Average loss at step', 3000, 'for last 250 steps:', 0.3995463865995407)
# ('Average loss at step', 3040, 'for last 250 steps:', 0.39607884526252746)
# ('Average loss at step', 3080, 'for last 250 steps:', 0.39324662446975706)
# ('Average loss at step', 3120, 'for last 250 steps:', 0.39703020751476287)
# ('Average loss at step', 3160, 'for last 250 steps:', 0.3985114586353302)
# ('Average loss at step', 3200, 'for last 250 steps:', 0.404335652589798)
# ('Average loss at step', 3240, 'for last 250 steps:', 0.3952990800142288)
# ('Average loss at step', 3280, 'for last 250 steps:', 0.3892691296339035)
# ('Average loss at step', 3320, 'for last 250 steps:', 0.3937980699539185)
# ('Average loss at step', 3360, 'for last 250 steps:', 0.3915679460763931)
# ('Average loss at step', 3400, 'for last 250 steps:', 0.39426246464252473)
# ('Average loss at step', 3440, 'for last 250 steps:', 0.3929010432958603)
# ('Average loss at step', 3480, 'for last 250 steps:', 0.3994822990894318)
# ('Average loss at step', 3520, 'for last 250 steps:', 0.3972520714998245)
# ('Average loss at step', 3560, 'for last 250 steps:', 0.3936389130353928)
# ('Average loss at step', 3600, 'for last 250 steps:', 0.37906370997428895)
# ('Average loss at step', 3640, 'for last 250 steps:', 0.38301696538925173)
# ('Average loss at step', 3680, 'for last 250 steps:', 0.382830570936203)
# ('Average loss at step', 3720, 'for last 250 steps:', 0.3882190829515457)
# ('Average loss at step', 3760, 'for last 250 steps:', 0.3884885382652283)
# ('Average loss at step', 3800, 'for last 250 steps:', 0.3892205619812012)
# ('Average loss at step', 3840, 'for last 250 steps:', 0.3836017990112305)
# ('Average loss at step', 3880, 'for last 250 steps:', 0.3931757628917694)
# ('Average loss at step', 3920, 'for last 250 steps:', 0.3850285255908966)
# ('Average loss at step', 3960, 'for last 250 steps:', 0.3815116739273071)
# ('\nEPOCH', 1)
# ('Average loss at step', 40, 'for last 250 steps:', 0.40243602156639097)
# ('Average loss at step', 80, 'for last 250 steps:', 0.38464586675167084)
# ('Average loss at step', 120, 'for last 250 steps:', 0.38305774867534637)
# ('Average loss at step', 160, 'for last 250 steps:', 0.384327238202095)
# ('Average loss at step', 200, 'for last 250 steps:', 0.38308158576488494)
# ('Average loss at step', 240, 'for last 250 steps:', 0.3884343284368515)
# ('Average loss at step', 280, 'for last 250 steps:', 0.3854629933834076)
# ('Average loss at step', 320, 'for last 250 steps:', 0.38416468143463134)
# ('Average loss at step', 360, 'for last 250 steps:', 0.3747248429059982)
# ('Average loss at step', 400, 'for last 250 steps:', 0.38905703723430635)
# ('Average loss at step', 440, 'for last 250 steps:', 0.3819890707731247)
# ('Average loss at step', 480, 'for last 250 steps:', 0.3847618019580841)
# ('Average loss at step', 520, 'for last 250 steps:', 0.3926149904727936)
# ('Average loss at step', 560, 'for last 250 steps:', 0.3917180013656616)
# ('Average loss at step', 600, 'for last 250 steps:', 0.38163943231105807)
# ('Average loss at step', 640, 'for last 250 steps:', 0.38543207466602325)
# ('Average loss at step', 680, 'for last 250 steps:', 0.37965048253536227)
# ('Average loss at step', 720, 'for last 250 steps:', 0.38414742290973664)
# ('Average loss at step', 760, 'for last 250 steps:', 0.38309351801872255)
# ('Average loss at step', 800, 'for last 250 steps:', 0.37624781668186186)
# ('Average loss at step', 840, 'for last 250 steps:', 0.385866185426712)
# ('Average loss at step', 880, 'for last 250 steps:', 0.38264139473438263)
# ('Average loss at step', 920, 'for last 250 steps:', 0.38440636694431307)
# ('Average loss at step', 960, 'for last 250 steps:', 0.3762723636627197)
# ('Average loss at step', 1000, 'for last 250 steps:', 0.38042641699314117)
# ('Average loss at step', 1040, 'for last 250 steps:', 0.38189343094825745)
# ('Average loss at step', 1080, 'for last 250 steps:', 0.3788011473417282)
# ('Average loss at step', 1120, 'for last 250 steps:', 0.37748636305332184)
# ('Average loss at step', 1160, 'for last 250 steps:', 0.3808675569295883)
# ('Average loss at step', 1200, 'for last 250 steps:', 0.379071946144104)
# ('Average loss at step', 1240, 'for last 250 steps:', 0.38230693578720093)
# ('Average loss at step', 1280, 'for last 250 steps:', 0.3700538390874863)
# ('Average loss at step', 1320, 'for last 250 steps:', 0.3749145144224167)
# ('Average loss at step', 1360, 'for last 250 steps:', 0.3791360026597977)
# ('Average loss at step', 1400, 'for last 250 steps:', 0.38124007999897)
# ('Average loss at step', 1440, 'for last 250 steps:', 0.38640086829662323)
# ('Average loss at step', 1480, 'for last 250 steps:', 0.3786510455608368)
# ('Average loss at step', 1520, 'for last 250 steps:', 0.37318173825740814)
# ('Average loss at step', 1560, 'for last 250 steps:', 0.3773767781257629)
# ('Average loss at step', 1600, 'for last 250 steps:', 0.37639433979988096)
# ('Average loss at step', 1640, 'for last 250 steps:', 0.3770235162973404)
# ('Average loss at step', 1680, 'for last 250 steps:', 0.3776521772146225)
# ('Average loss at step', 1720, 'for last 250 steps:', 0.38253015518188477)
# ('Average loss at step', 1760, 'for last 250 steps:', 0.3758810007572174)
# ('Average loss at step', 1800, 'for last 250 steps:', 0.38350282192230223)
# ('Average loss at step', 1840, 'for last 250 steps:', 0.37986210465431214)
# ('Average loss at step', 1880, 'for last 250 steps:', 0.3789332699775696)
# ('Average loss at step', 1920, 'for last 250 steps:', 0.37789429366588595)
# ('Average loss at step', 1960, 'for last 250 steps:', 0.37271631479263306)
# ('Average loss at step', 2000, 'for last 250 steps:', 0.3708104091882706)
# ('Average loss at step', 2040, 'for last 250 steps:', 0.38355840802192687)
# ('Average loss at step', 2080, 'for last 250 steps:', 0.3730402326583862)
# ('Average loss at step', 2120, 'for last 250 steps:', 0.3799690228700638)
# ('Average loss at step', 2160, 'for last 250 steps:', 0.38028553664684295)
# ('Average loss at step', 2200, 'for last 250 steps:', 0.38003080666065214)
# ('Average loss at step', 2240, 'for last 250 steps:', 0.3790423423051834)
# ('Average loss at step', 2280, 'for last 250 steps:', 0.37688618659973144)
# ('Average loss at step', 2320, 'for last 250 steps:', 0.37400491058826446)
# ('Average loss at step', 2360, 'for last 250 steps:', 0.3768589448928833)
# ('Average loss at step', 2400, 'for last 250 steps:', 0.3745914155244827)
# ('Average loss at step', 2440, 'for last 250 steps:', 0.3796280026435852)
# ('Average loss at step', 2480, 'for last 250 steps:', 0.3793249869346619)
# ('Average loss at step', 2520, 'for last 250 steps:', 0.3754300713539124)
# ('Average loss at step', 2560, 'for last 250 steps:', 0.3716062027215958)
# ('Average loss at step', 2600, 'for last 250 steps:', 0.3761087381839752)
# ('Average loss at step', 2640, 'for last 250 steps:', 0.37052941620349883)
# ('Average loss at step', 2680, 'for last 250 steps:', 0.3805729526281357)
# ('Average loss at step', 2720, 'for last 250 steps:', 0.37911716759204867)
# ('Average loss at step', 2760, 'for last 250 steps:', 0.369655721783638)
# ('Average loss at step', 2800, 'for last 250 steps:', 0.3787514036893845)
# ('Average loss at step', 2840, 'for last 250 steps:', 0.37422057151794436)
# ('Average loss at step', 2880, 'for last 250 steps:', 0.37941224336624146)
# ('Average loss at step', 2920, 'for last 250 steps:', 0.3739800953865051)
# ('Average loss at step', 2960, 'for last 250 steps:', 0.37361090183258056)
# ('Average loss at step', 3000, 'for last 250 steps:', 0.3741825932264328)
# ('Average loss at step', 3040, 'for last 250 steps:', 0.37359444618225096)
# ('Average loss at step', 3080, 'for last 250 steps:', 0.3698813444375992)
# ('Average loss at step', 3120, 'for last 250 steps:', 0.37868837535381317)
# ('Average loss at step', 3160, 'for last 250 steps:', 0.37524868428707125)
# ('Average loss at step', 3200, 'for last 250 steps:', 0.3744090849161148)
# ('Average loss at step', 3240, 'for last 250 steps:', 0.37851052105426786)
# ('Average loss at step', 3280, 'for last 250 steps:', 0.3690124315023422)
# ('Average loss at step', 3320, 'for last 250 steps:', 0.3653556680679321)
# ('Average loss at step', 3360, 'for last 250 steps:', 0.3647594702243805)
# ('Average loss at step', 3400, 'for last 250 steps:', 0.3736210471391678)
# ('Average loss at step', 3440, 'for last 250 steps:', 0.37261405944824216)
# ('Average loss at step', 3480, 'for last 250 steps:', 0.3719953984022141)
# ('Average loss at step', 3520, 'for last 250 steps:', 0.36574804067611694)
# ('Average loss at step', 3560, 'for last 250 steps:', 0.3764179885387421)
# ('Average loss at step', 3600, 'for last 250 steps:', 0.3720968061685562)
# ('Average loss at step', 3640, 'for last 250 steps:', 0.3729954421520233)
# ('Average loss at step', 3680, 'for last 250 steps:', 0.3782667237520218)
# ('Average loss at step', 3720, 'for last 250 steps:', 0.37058717250823975)
# ('Average loss at step', 3760, 'for last 250 steps:', 0.36899606585502626)
# ('Average loss at step', 3800, 'for last 250 steps:', 0.37537929594516756)
# ('Average loss at step', 3840, 'for last 250 steps:', 0.3778837549686432)
# ('Average loss at step', 3880, 'for last 250 steps:', 0.3762028902769089)
# ('Average loss at step', 3920, 'for last 250 steps:', 0.37827995002269743)
# ('Average loss at step', 3960, 'for last 250 steps:', 0.3719358038902283)
# ('\nEPOCH', 2)
# ('Average loss at step', 40, 'for last 250 steps:', 0.38243830263614653)
# ('Average loss at step', 80, 'for last 250 steps:', 0.3665997493267059)
# ('Average loss at step', 120, 'for last 250 steps:', 0.37811658322811126)
# ('Average loss at step', 160, 'for last 250 steps:', 0.3659042185544968)
# ('Average loss at step', 200, 'for last 250 steps:', 0.372931627035141)
# ('Average loss at step', 240, 'for last 250 steps:', 0.3677699112892151)
# ('Average loss at step', 280, 'for last 250 steps:', 0.36734897792339327)
# ('Average loss at step', 320, 'for last 250 steps:', 0.38004954636096955)
# ('Average loss at step', 360, 'for last 250 steps:', 0.3745915901660919)
# ('Average loss at step', 400, 'for last 250 steps:', 0.36672779738903044)
# ('Average loss at step', 440, 'for last 250 steps:', 0.3734587794542313)
# ('Average loss at step', 480, 'for last 250 steps:', 0.3639023631811142)
# ('Average loss at step', 520, 'for last 250 steps:', 0.37285162568092345)
# ('Average loss at step', 560, 'for last 250 steps:', 0.3746308636665344)
# ('Average loss at step', 600, 'for last 250 steps:', 0.3778032207489014)
# ('Average loss at step', 640, 'for last 250 steps:', 0.3759577226638794)
# ('Average loss at step', 680, 'for last 250 steps:', 0.3727908080816269)
# ('Average loss at step', 720, 'for last 250 steps:', 0.3759753233194351)
# ('Average loss at step', 760, 'for last 250 steps:', 0.3830941742658615)
# ('Average loss at step', 800, 'for last 250 steps:', 0.363812609910965)
# ('Average loss at step', 840, 'for last 250 steps:', 0.36307776808738706)
# ('Average loss at step', 880, 'for last 250 steps:', 0.3701659572124481)
# ('Average loss at step', 920, 'for last 250 steps:', 0.37240942180156705)
# ('Average loss at step', 960, 'for last 250 steps:', 0.3618719261884689)
# ('Average loss at step', 1000, 'for last 250 steps:', 0.3656188476085663)
# ('Average loss at step', 1040, 'for last 250 steps:', 0.37125753343105317)
# ('Average loss at step', 1080, 'for last 250 steps:', 0.36956817865371705)
# ('Average loss at step', 1120, 'for last 250 steps:', 0.36934930324554444)
# ('Average loss at step', 1160, 'for last 250 steps:', 0.375237495303154)
# ('Average loss at step', 1200, 'for last 250 steps:', 0.36482283055782316)
# ('Average loss at step', 1240, 'for last 250 steps:', 0.3701731926202774)
# ('Average loss at step', 1280, 'for last 250 steps:', 0.3651579225063324)
# ('Average loss at step', 1320, 'for last 250 steps:', 0.3683526587486267)
# ('Average loss at step', 1360, 'for last 250 steps:', 0.365862472653389)
# ('Average loss at step', 1400, 'for last 250 steps:', 0.3707027393579483)
# ('Average loss at step', 1440, 'for last 250 steps:', 0.37296602547168733)
# ('Average loss at step', 1480, 'for last 250 steps:', 0.36792112529277804)
# ('Average loss at step', 1520, 'for last 250 steps:', 0.3744408828020096)
# ('Average loss at step', 1560, 'for last 250 steps:', 0.3673870849609375)
# ('Average loss at step', 1600, 'for last 250 steps:', 0.3687689459323883)
# ('Average loss at step', 1640, 'for last 250 steps:', 0.3676986461877823)
# ('Average loss at step', 1680, 'for last 250 steps:', 0.3684005630016327)
# ('Average loss at step', 1720, 'for last 250 steps:', 0.36161453545093536)
# ('Average loss at step', 1760, 'for last 250 steps:', 0.3711200219392776)
# ('Average loss at step', 1800, 'for last 250 steps:', 0.3693909192085266)
# ('Average loss at step', 1840, 'for last 250 steps:', 0.374088317155838)
# ('Average loss at step', 1880, 'for last 250 steps:', 0.36764229238033297)
# ('Average loss at step', 1920, 'for last 250 steps:', 0.3664361047744751)
# ('Average loss at step', 1960, 'for last 250 steps:', 0.3679438203573227)
# ('Average loss at step', 2000, 'for last 250 steps:', 0.3747196751832962)
# ('Average loss at step', 2040, 'for last 250 steps:', 0.3597642916440964)
# ('Average loss at step', 2080, 'for last 250 steps:', 0.37275310039520265)
# ('Average loss at step', 2120, 'for last 250 steps:', 0.36428693354129793)
# ('Average loss at step', 2160, 'for last 250 steps:', 0.3745029181241989)
# ('Average loss at step', 2200, 'for last 250 steps:', 0.36962593972682956)
# ('Average loss at step', 2240, 'for last 250 steps:', 0.36091847240924835)
# ('Average loss at step', 2280, 'for last 250 steps:', 0.37257243812084195)
# ('Average loss at step', 2320, 'for last 250 steps:', 0.3676090723276138)
# ('Average loss at step', 2360, 'for last 250 steps:', 0.37349889636039735)
# ('Average loss at step', 2400, 'for last 250 steps:', 0.3681676781177521)
# ('Average loss at step', 2440, 'for last 250 steps:', 0.37508468568325043)
# ('Average loss at step', 2480, 'for last 250 steps:', 0.3637095934152603)
# ('Average loss at step', 2520, 'for last 250 steps:', 0.3692040139436722)
# ('Average loss at step', 2560, 'for last 250 steps:', 0.3740474385023117)
# ('Average loss at step', 2600, 'for last 250 steps:', 0.3778780221939087)
# ('Average loss at step', 2640, 'for last 250 steps:', 0.3760091608762741)
# ('Average loss at step', 2680, 'for last 250 steps:', 0.3745859169960022)
# ('Average loss at step', 2720, 'for last 250 steps:', 0.3685914558172226)
# ('Average loss at step', 2760, 'for last 250 steps:', 0.3655525815486908)
# ('Average loss at step', 2800, 'for last 250 steps:', 0.373238023519516)
# ('Average loss at step', 2840, 'for last 250 steps:', 0.36270419239997864)
# ('Average loss at step', 2880, 'for last 250 steps:', 0.3730194860696793)
# ('Average loss at step', 2920, 'for last 250 steps:', 0.3674549585580826)
# ('Average loss at step', 2960, 'for last 250 steps:', 0.3735057777166367)
# ('Average loss at step', 3000, 'for last 250 steps:', 0.3677064347267151)
# ('Average loss at step', 3040, 'for last 250 steps:', 0.3704030114412308)
# ('Average loss at step', 3080, 'for last 250 steps:', 0.3575349968671799)
# ('Average loss at step', 3120, 'for last 250 steps:', 0.3632851022481918)
# ('Average loss at step', 3160, 'for last 250 steps:', 0.37000918030738833)
# ('Average loss at step', 3200, 'for last 250 steps:', 0.3723317342996597)
# ('Average loss at step', 3240, 'for last 250 steps:', 0.37209689497947696)
# ('Average loss at step', 3280, 'for last 250 steps:', 0.3709787434339523)
# ('Average loss at step', 3320, 'for last 250 steps:', 0.36878606140613557)
# ('Average loss at step', 3360, 'for last 250 steps:', 0.37189683854579925)
# ('Average loss at step', 3400, 'for last 250 steps:', 0.37275181770324706)
# ('Average loss at step', 3440, 'for last 250 steps:', 0.37173261046409606)
# ('Average loss at step', 3480, 'for last 250 steps:', 0.3647876566648483)
# ('Average loss at step', 3520, 'for last 250 steps:', 0.36855938136577604)
# ('Average loss at step', 3560, 'for last 250 steps:', 0.35877066493034365)
# ('Average loss at step', 3600, 'for last 250 steps:', 0.36735602378845217)
# ('Average loss at step', 3640, 'for last 250 steps:', 0.366818825006485)
# ('Average loss at step', 3680, 'for last 250 steps:', 0.3682123988866806)
# ('Average loss at step', 3720, 'for last 250 steps:', 0.36836901903152464)
# ('Average loss at step', 3760, 'for last 250 steps:', 0.3693497848510742)
# ('Average loss at step', 3800, 'for last 250 steps:', 0.3650202798843384)
# ('Average loss at step', 3840, 'for last 250 steps:', 0.3737060391902924)
# ('Average loss at step', 3880, 'for last 250 steps:', 0.35844634115695956)
# ('Average loss at step', 3920, 'for last 250 steps:', 0.368913825750351)
# ('Average loss at step', 3960, 'for last 250 steps:', 0.3680823826789856)
# ('\nEPOCH', 3)
# ('Average loss at step', 40, 'for last 250 steps:', 0.37737396895885467)
# ('Average loss at step', 80, 'for last 250 steps:', 0.3669338262081146)
# ('Average loss at step', 120, 'for last 250 steps:', 0.36760843217372896)
# ('Average loss at step', 160, 'for last 250 steps:', 0.365975478887558)
# ('Average loss at step', 200, 'for last 250 steps:', 0.3694224518537521)
# ('Average loss at step', 240, 'for last 250 steps:', 0.3566861814260483)
# ('Average loss at step', 280, 'for last 250 steps:', 0.3704455381631851)
# ('Average loss at step', 320, 'for last 250 steps:', 0.3678060108423233)
# ('Average loss at step', 360, 'for last 250 steps:', 0.36980717480182645)
# ('Average loss at step', 400, 'for last 250 steps:', 0.37396477043628695)
# ('Average loss at step', 440, 'for last 250 steps:', 0.36792128801345825)
# ('Average loss at step', 480, 'for last 250 steps:', 0.36248515188694)
# ('Average loss at step', 520, 'for last 250 steps:', 0.364955461025238)
# ('Average loss at step', 560, 'for last 250 steps:', 0.36958962500095366)
# ('Average loss at step', 600, 'for last 250 steps:', 0.3726544296741486)
# ('Average loss at step', 640, 'for last 250 steps:', 0.3724870604276657)
# ('Average loss at step', 680, 'for last 250 steps:', 0.3669249486923218)
# ('Average loss at step', 720, 'for last 250 steps:', 0.3672072583436966)
# ('Average loss at step', 760, 'for last 250 steps:', 0.36135790109634397)
# ('Average loss at step', 800, 'for last 250 steps:', 0.35979138791561127)
# ('Average loss at step', 840, 'for last 250 steps:', 0.37011284470558165)
# ('Average loss at step', 880, 'for last 250 steps:', 0.36897208511829377)
# ('Average loss at step', 920, 'for last 250 steps:', 0.36410114765167234)
# ('Average loss at step', 960, 'for last 250 steps:', 0.36964444994926454)
# ('Average loss at step', 1000, 'for last 250 steps:', 0.36537555992603304)
# ('Average loss at step', 1040, 'for last 250 steps:', 0.3758855140209198)
# ('Average loss at step', 1080, 'for last 250 steps:', 0.3689254432916641)
# ('Average loss at step', 1120, 'for last 250 steps:', 0.36300633490085604)
# ('Average loss at step', 1160, 'for last 250 steps:', 0.37097555994987486)
# ('Average loss at step', 1200, 'for last 250 steps:', 0.3667931133508682)
# ('Average loss at step', 1240, 'for last 250 steps:', 0.36831169307231904)
# ('Average loss at step', 1280, 'for last 250 steps:', 0.3619519937038422)
# ('Average loss at step', 1320, 'for last 250 steps:', 0.3672338569164276)
# ('Average loss at step', 1360, 'for last 250 steps:', 0.3695743775367737)
# ('Average loss at step', 1400, 'for last 250 steps:', 0.36685961961746216)
# ('Average loss at step', 1440, 'for last 250 steps:', 0.3707796615362167)
# ('Average loss at step', 1480, 'for last 250 steps:', 0.3593762266635895)
# ('Average loss at step', 1520, 'for last 250 steps:', 0.3701143872737884)
# ('Average loss at step', 1560, 'for last 250 steps:', 0.3675497508049011)
# ('Average loss at step', 1600, 'for last 250 steps:', 0.3716742688417435)
# ('Average loss at step', 1640, 'for last 250 steps:', 0.3669165599346161)
# ('Average loss at step', 1680, 'for last 250 steps:', 0.3678591048717499)
# ('Average loss at step', 1720, 'for last 250 steps:', 0.36350076019763944)
# ('Average loss at step', 1760, 'for last 250 steps:', 0.3681266564130783)
# ('Average loss at step', 1800, 'for last 250 steps:', 0.35877500355243686)
# ('Average loss at step', 1840, 'for last 250 steps:', 0.36596457064151766)
# ('Average loss at step', 1880, 'for last 250 steps:', 0.36718358516693117)
# ('Average loss at step', 1920, 'for last 250 steps:', 0.37247449219226836)
# ('Average loss at step', 1960, 'for last 250 steps:', 0.36609641432762147)
# ('Average loss at step', 2000, 'for last 250 steps:', 0.3681789791584015)
# ('Average loss at step', 2040, 'for last 250 steps:', 0.3643410193920136)
# ('Average loss at step', 2080, 'for last 250 steps:', 0.36222721040248873)
# ('Average loss at step', 2120, 'for last 250 steps:', 0.36987079560756686)
# ('Average loss at step', 2160, 'for last 250 steps:', 0.36354777216911316)
# ('Average loss at step', 2200, 'for last 250 steps:', 0.36540124714374544)
# ('Average loss at step', 2240, 'for last 250 steps:', 0.3718492740392685)
# ('Average loss at step', 2280, 'for last 250 steps:', 0.36623834669589994)
# ('Average loss at step', 2320, 'for last 250 steps:', 0.358107795715332)
# ('Average loss at step', 2360, 'for last 250 steps:', 0.3653630048036575)
# ('Average loss at step', 2400, 'for last 250 steps:', 0.3645230686664581)
# ('Average loss at step', 2440, 'for last 250 steps:', 0.36162838220596316)
# ('Average loss at step', 2480, 'for last 250 steps:', 0.3794239193201065)
# ('Average loss at step', 2520, 'for last 250 steps:', 0.3638757836818695)
# ('Average loss at step', 2560, 'for last 250 steps:', 0.37081224977970123)
# ('Average loss at step', 2600, 'for last 250 steps:', 0.3690412908792496)
# ('Average loss at step', 2640, 'for last 250 steps:', 0.3642549866437912)
# ('Average loss at step', 2680, 'for last 250 steps:', 0.3710361856222153)
# ('Average loss at step', 2720, 'for last 250 steps:', 0.36121956586837767)
# ('Average loss at step', 2760, 'for last 250 steps:', 0.35699694871902465)
# ('Average loss at step', 2800, 'for last 250 steps:', 0.362247850894928)
# ('Average loss at step', 2840, 'for last 250 steps:', 0.3656926357746124)
# ('Average loss at step', 2880, 'for last 250 steps:', 0.36539297461509707)
# ('Average loss at step', 2920, 'for last 250 steps:', 0.3665246492624283)
# ('Average loss at step', 2960, 'for last 250 steps:', 0.3595507210493088)
# ('Average loss at step', 3000, 'for last 250 steps:', 0.3626909279823303)
# ('Average loss at step', 3040, 'for last 250 steps:', 0.36502905905246735)
# ('Average loss at step', 3080, 'for last 250 steps:', 0.3585678082704544)
# ('Average loss at step', 3120, 'for last 250 steps:', 0.35970626831054686)
# ('Average loss at step', 3160, 'for last 250 steps:', 0.35900379955768585)
# ('Average loss at step', 3200, 'for last 250 steps:', 0.36106931388378144)
# ('Average loss at step', 3240, 'for last 250 steps:', 0.3600194603204727)
# ('Average loss at step', 3280, 'for last 250 steps:', 0.3728572142124176)
# ('Average loss at step', 3320, 'for last 250 steps:', 0.36663047432899476)
# ('Average loss at step', 3360, 'for last 250 steps:', 0.3603346973657608)
# ('Average loss at step', 3400, 'for last 250 steps:', 0.36061601638793944)
# ('Average loss at step', 3440, 'for last 250 steps:', 0.36361681640148164)
# ('Average loss at step', 3480, 'for last 250 steps:', 0.36792485177516937)
# ('Average loss at step', 3520, 'for last 250 steps:', 0.3649249011278152)
# ('Average loss at step', 3560, 'for last 250 steps:', 0.3650317776203156)
# ('Average loss at step', 3600, 'for last 250 steps:', 0.36651653110980986)
# ('Average loss at step', 3640, 'for last 250 steps:', 0.3606912785768509)
# ('Average loss at step', 3680, 'for last 250 steps:', 0.36538252532482146)
# ('Average loss at step', 3720, 'for last 250 steps:', 0.3694982463121414)
# ('Average loss at step', 3760, 'for last 250 steps:', 0.3628778213262558)
# ('Average loss at step', 3800, 'for last 250 steps:', 0.36282977104187014)
# ('Average loss at step', 3840, 'for last 250 steps:', 0.3651708787679672)
# ('Average loss at step', 3880, 'for last 250 steps:', 0.3659814989566803)
# ('Average loss at step', 3920, 'for last 250 steps:', 0.3650779914855957)
# ('Average loss at step', 3960, 'for last 250 steps:', 0.3577535116672516)
# ('\nEPOCH', 4)
# ('Average loss at step', 40, 'for last 250 steps:', 0.3792958641052246)
# ('Average loss at step', 80, 'for last 250 steps:', 0.3653822636604309)
# ('Average loss at step', 120, 'for last 250 steps:', 0.36610708236694334)
# ('Average loss at step', 160, 'for last 250 steps:', 0.3583793604373932)
# ('Average loss at step', 200, 'for last 250 steps:', 0.3697867965698242)
# ('Average loss at step', 240, 'for last 250 steps:', 0.3707009834051132)
# ('Average loss at step', 280, 'for last 250 steps:', 0.3594041574001312)
# ('Average loss at step', 320, 'for last 250 steps:', 0.36370603561401366)
# ('Average loss at step', 360, 'for last 250 steps:', 0.3654002094268799)
# ('Average loss at step', 400, 'for last 250 steps:', 0.36129943311214446)
# ('Average loss at step', 440, 'for last 250 steps:', 0.36389367759227753)
# ('Average loss at step', 480, 'for last 250 steps:', 0.3708653753995895)
# ('Average loss at step', 520, 'for last 250 steps:', 0.3644274652004242)
# ('Average loss at step', 560, 'for last 250 steps:', 0.35979375302791594)
# ('Average loss at step', 600, 'for last 250 steps:', 0.365012526512146)
# ('Average loss at step', 640, 'for last 250 steps:', 0.361446977853775)
# ('Average loss at step', 680, 'for last 250 steps:', 0.35830182015895845)
# ('Average loss at step', 720, 'for last 250 steps:', 0.36524988114833834)
# ('Average loss at step', 760, 'for last 250 steps:', 0.36789084136486055)
# ('Average loss at step', 800, 'for last 250 steps:', 0.3598640513420105)
# ('Average loss at step', 840, 'for last 250 steps:', 0.3728809958696365)
# ('Average loss at step', 880, 'for last 250 steps:', 0.365566623210907)
# ('Average loss at step', 920, 'for last 250 steps:', 0.3650930553674698)
# ('Average loss at step', 960, 'for last 250 steps:', 0.36317808628082277)
# ('Average loss at step', 1000, 'for last 250 steps:', 0.3671054792404175)
# ('Average loss at step', 1040, 'for last 250 steps:', 0.35640548408031464)
# ('Average loss at step', 1080, 'for last 250 steps:', 0.3591098189353943)
# ('Average loss at step', 1120, 'for last 250 steps:', 0.3613354641199112)
# ('Average loss at step', 1160, 'for last 250 steps:', 0.36566862821578977)
# ('Average loss at step', 1200, 'for last 250 steps:', 0.36276536285877226)
# ('Average loss at step', 1240, 'for last 250 steps:', 0.3717632418870926)
# ('Average loss at step', 1280, 'for last 250 steps:', 0.36038979053497316)
# ('Average loss at step', 1320, 'for last 250 steps:', 0.3650651812553406)
# ('Average loss at step', 1360, 'for last 250 steps:', 0.3628745895624161)
# ('Average loss at step', 1400, 'for last 250 steps:', 0.36243204414844515)
# ('Average loss at step', 1440, 'for last 250 steps:', 0.3705330890417099)
# ('Average loss at step', 1480, 'for last 250 steps:', 0.36367092132568357)
# ('Average loss at step', 1520, 'for last 250 steps:', 0.3635533595085144)
# ('Average loss at step', 1560, 'for last 250 steps:', 0.36453633248806)
# ('Average loss at step', 1600, 'for last 250 steps:', 0.3688955992460251)
# ('Average loss at step', 1640, 'for last 250 steps:', 0.36599342346191405)
# ('Average loss at step', 1680, 'for last 250 steps:', 0.3628367602825165)
# ('Average loss at step', 1720, 'for last 250 steps:', 0.35924773454666137)
# ('Average loss at step', 1760, 'for last 250 steps:', 0.36252999424934385)
# ('Average loss at step', 1800, 'for last 250 steps:', 0.3615570247173309)
# ('Average loss at step', 1840, 'for last 250 steps:', 0.3671477538347244)
# ('Average loss at step', 1880, 'for last 250 steps:', 0.3664287853240967)
# ('Average loss at step', 1920, 'for last 250 steps:', 0.3598977708816528)
# ('Average loss at step', 1960, 'for last 250 steps:', 0.3622050929069519)
# ('Average loss at step', 2000, 'for last 250 steps:', 0.3644685071706772)
# ('Average loss at step', 2040, 'for last 250 steps:', 0.36690117835998537)
# ('Average loss at step', 2080, 'for last 250 steps:', 0.3642087286710739)
# ('Average loss at step', 2120, 'for last 250 steps:', 0.3682969129085541)
# ('Average loss at step', 2160, 'for last 250 steps:', 0.3677514833211899)
# ('Average loss at step', 2200, 'for last 250 steps:', 0.3656171578168869)
# ('Average loss at step', 2240, 'for last 250 steps:', 0.3649657690525055)
# ('Average loss at step', 2280, 'for last 250 steps:', 0.3663433200120926)
# ('Average loss at step', 2320, 'for last 250 steps:', 0.35870992302894594)
# ('Average loss at step', 2360, 'for last 250 steps:', 0.3634624618291855)
# ('Average loss at step', 2400, 'for last 250 steps:', 0.3608740347623825)
# ('Average loss at step', 2440, 'for last 250 steps:', 0.3751976776123047)
# ('Average loss at step', 2480, 'for last 250 steps:', 0.3620758867263794)
# ('Average loss at step', 2520, 'for last 250 steps:', 0.3612908577919006)
# ('Average loss at step', 2560, 'for last 250 steps:', 0.36783648252487183)
# ('Average loss at step', 2600, 'for last 250 steps:', 0.36081643164157867)
# ('Average loss at step', 2640, 'for last 250 steps:', 0.37095817267894743)
# ('Average loss at step', 2680, 'for last 250 steps:', 0.35740801572799685)
# ('Average loss at step', 2720, 'for last 250 steps:', 0.3624777692556381)
# ('Average loss at step', 2760, 'for last 250 steps:', 0.3655575096607208)
# ('Average loss at step', 2800, 'for last 250 steps:', 0.35886635959148405)
# ('Average loss at step', 2840, 'for last 250 steps:', 0.3639876186847687)
# ('Average loss at step', 2880, 'for last 250 steps:', 0.36014173686504364)
# ('Average loss at step', 2920, 'for last 250 steps:', 0.3697811758518219)
# ('Average loss at step', 2960, 'for last 250 steps:', 0.3553344422578812)
# ('Average loss at step', 3000, 'for last 250 steps:', 0.35857572793960574)
# ('Average loss at step', 3040, 'for last 250 steps:', 0.35811431586742404)
# ('Average loss at step', 3080, 'for last 250 steps:', 0.3613723433017731)
# ('Average loss at step', 3120, 'for last 250 steps:', 0.3565449744462967)
# ('Average loss at step', 3160, 'for last 250 steps:', 0.3620313709974289)
# ('Average loss at step', 3200, 'for last 250 steps:', 0.36102775812149046)
# ('Average loss at step', 3240, 'for last 250 steps:', 0.35949316501617434)
# ('Average loss at step', 3280, 'for last 250 steps:', 0.3632038241624832)
# ('Average loss at step', 3320, 'for last 250 steps:', 0.3613610792160034)
# ('Average loss at step', 3360, 'for last 250 steps:', 0.3662463891506195)
# ('Average loss at step', 3400, 'for last 250 steps:', 0.36617127418518064)
# ('Average loss at step', 3440, 'for last 250 steps:', 0.36270698547363284)
# ('Average loss at step', 3480, 'for last 250 steps:', 0.3714647603034973)
# ('Average loss at step', 3520, 'for last 250 steps:', 0.3692722684144974)
# ('Average loss at step', 3560, 'for last 250 steps:', 0.35306514501571656)
# ('Average loss at step', 3600, 'for last 250 steps:', 0.3648150533437729)
# ('Average loss at step', 3640, 'for last 250 steps:', 0.35667637884616854)
# ('Average loss at step', 3680, 'for last 250 steps:', 0.36136075913906096)
# ('Average loss at step', 3720, 'for last 250 steps:', 0.36329887568950653)
# ('Average loss at step', 3760, 'for last 250 steps:', 0.36538568437099456)
# ('Average loss at step', 3800, 'for last 250 steps:', 0.3531907510757446)
# ('Average loss at step', 3840, 'for last 250 steps:', 0.36635072112083433)
# ('Average loss at step', 3880, 'for last 250 steps:', 0.36580884754657744)
# ('Average loss at step', 3920, 'for last 250 steps:', 0.36312170267105104)
# ('Average loss at step', 3960, 'for last 250 steps:', 0.35538961589336393)
# ('\nEPOCH', 5)
# ('Average loss at step', 40, 'for last 250 steps:', 0.3732671576738358)
# ('Average loss at step', 80, 'for last 250 steps:', 0.3613810074329376)
# ('Average loss at step', 120, 'for last 250 steps:', 0.36529150784015657)
# ('Average loss at step', 160, 'for last 250 steps:', 0.36267671048641204)
# ('Average loss at step', 200, 'for last 250 steps:', 0.37037177979946134)
# ('Average loss at step', 240, 'for last 250 steps:', 0.3604656732082367)
# ('Average loss at step', 280, 'for last 250 steps:', 0.3584597373008728)
# ('Average loss at step', 320, 'for last 250 steps:', 0.3573945516347885)
# ('Average loss at step', 360, 'for last 250 steps:', 0.364445173740387)
# ('Average loss at step', 400, 'for last 250 steps:', 0.3759448480606079)
# ('Average loss at step', 440, 'for last 250 steps:', 0.3622191137075424)
# ('Average loss at step', 480, 'for last 250 steps:', 0.3607691031694412)
# ('Average loss at step', 520, 'for last 250 steps:', 0.36057532429695127)
# ('Average loss at step', 560, 'for last 250 steps:', 0.36312941610813143)
# ('Average loss at step', 600, 'for last 250 steps:', 0.3677599209547043)
# ('Average loss at step', 640, 'for last 250 steps:', 0.362172018289566)
# ('Average loss at step', 680, 'for last 250 steps:', 0.3568227875232697)
# ('Average loss at step', 720, 'for last 250 steps:', 0.36698634207248687)
# ('Average loss at step', 760, 'for last 250 steps:', 0.36686770677566527)
# ('Average loss at step', 800, 'for last 250 steps:', 0.35566583156585696)
# ('Average loss at step', 840, 'for last 250 steps:', 0.36124277353286743)
# ('Average loss at step', 880, 'for last 250 steps:', 0.36674240946769715)
# ('Average loss at step', 920, 'for last 250 steps:', 0.3670917171239853)
# ('Average loss at step', 960, 'for last 250 steps:', 0.3634987097978592)
# ('Average loss at step', 1000, 'for last 250 steps:', 0.3690971875190735)
# ('Average loss at step', 1040, 'for last 250 steps:', 0.3628771191835403)
# ('Average loss at step', 1080, 'for last 250 steps:', 0.36527217566967013)
# ('Average loss at step', 1120, 'for last 250 steps:', 0.3629887807369232)
# ('Average loss at step', 1160, 'for last 250 steps:', 0.3584193748235702)
# ('Average loss at step', 1200, 'for last 250 steps:', 0.3655879640579224)
# ('Average loss at step', 1240, 'for last 250 steps:', 0.362424076795578)
# ('Average loss at step', 1280, 'for last 250 steps:', 0.36123636722564695)
# ('Average loss at step', 1320, 'for last 250 steps:', 0.3623544853925705)
# ('Average loss at step', 1360, 'for last 250 steps:', 0.3576580673456192)
# ('Average loss at step', 1400, 'for last 250 steps:', 0.35295488774776457)
# ('Average loss at step', 1440, 'for last 250 steps:', 0.36709466636180876)
# ('Average loss at step', 1480, 'for last 250 steps:', 0.3649554485082626)
# ('Average loss at step', 1520, 'for last 250 steps:', 0.3591604310274124)
# ('Average loss at step', 1560, 'for last 250 steps:', 0.35907388806343077)
# ('Average loss at step', 1600, 'for last 250 steps:', 0.3668696826696396)
# ('Average loss at step', 1640, 'for last 250 steps:', 0.37196953773498537)
# ('Average loss at step', 1680, 'for last 250 steps:', 0.3706570219993591)
# ('Average loss at step', 1720, 'for last 250 steps:', 0.36178320825099947)
# ('Average loss at step', 1760, 'for last 250 steps:', 0.3624809557199478)
# ('Average loss at step', 1800, 'for last 250 steps:', 0.35770642280578613)
# ('Average loss at step', 1840, 'for last 250 steps:', 0.3665881437063217)
# ('Average loss at step', 1880, 'for last 250 steps:', 0.35821424305439)
# ('Average loss at step', 1920, 'for last 250 steps:', 0.3553984135389328)
# ('Average loss at step', 1960, 'for last 250 steps:', 0.36202212035655973)
# ('Average loss at step', 2000, 'for last 250 steps:', 0.3698125547170639)
# ('Average loss at step', 2040, 'for last 250 steps:', 0.35960390031337736)
# ('Average loss at step', 2080, 'for last 250 steps:', 0.35806254208087923)
# ('Average loss at step', 2120, 'for last 250 steps:', 0.36568142533302306)
# ('Average loss at step', 2160, 'for last 250 steps:', 0.36450768887996676)
# ('Average loss at step', 2200, 'for last 250 steps:', 0.3591911870241165)
# ('Average loss at step', 2240, 'for last 250 steps:', 0.36338791489601135)
# ('Average loss at step', 2280, 'for last 250 steps:', 0.36437291502952573)
# ('Average loss at step', 2320, 'for last 250 steps:', 0.3719914066791534)
# ('Average loss at step', 2360, 'for last 250 steps:', 0.3604540765285492)
# ('Average loss at step', 2400, 'for last 250 steps:', 0.3565675908327103)
# ('Average loss at step', 2440, 'for last 250 steps:', 0.35848248064517974)
# ('Average loss at step', 2480, 'for last 250 steps:', 0.3620918917655945)
# ('Average loss at step', 2520, 'for last 250 steps:', 0.36426284432411193)
# ('Average loss at step', 2560, 'for last 250 steps:', 0.360785009264946)
# ('Average loss at step', 2600, 'for last 250 steps:', 0.35693264126777646)
# ('Average loss at step', 2640, 'for last 250 steps:', 0.35966772317886353)
# ('Average loss at step', 2680, 'for last 250 steps:', 0.36201239824295045)
# ('Average loss at step', 2720, 'for last 250 steps:', 0.3711222457885742)
# ('Average loss at step', 2760, 'for last 250 steps:', 0.36255404353141785)
# ('Average loss at step', 2800, 'for last 250 steps:', 0.36002672016620635)
# ('Average loss at step', 2840, 'for last 250 steps:', 0.364365798830986)
# ('Average loss at step', 2880, 'for last 250 steps:', 0.3589410573244095)
# ('Average loss at step', 2920, 'for last 250 steps:', 0.3552343851327896)
# ('Average loss at step', 2960, 'for last 250 steps:', 0.351741201877594)
# ('Average loss at step', 3000, 'for last 250 steps:', 0.35343170940876006)
# ('Average loss at step', 3040, 'for last 250 steps:', 0.36381029784679414)
# ('Average loss at step', 3080, 'for last 250 steps:', 0.35747674107551575)
# ('Average loss at step', 3120, 'for last 250 steps:', 0.3605084753036499)
# ('Average loss at step', 3160, 'for last 250 steps:', 0.3591736662387848)
# ('Average loss at step', 3200, 'for last 250 steps:', 0.36587950587272644)
# ('Average loss at step', 3240, 'for last 250 steps:', 0.3647410601377487)
# ('Average loss at step', 3280, 'for last 250 steps:', 0.3700108963251114)
# ('Average loss at step', 3320, 'for last 250 steps:', 0.36603372275829316)
# ('Average loss at step', 3360, 'for last 250 steps:', 0.3607679843902588)
# ('Average loss at step', 3400, 'for last 250 steps:', 0.35792018711566925)
# ('Average loss at step', 3440, 'for last 250 steps:', 0.36091664016246794)
# ('Average loss at step', 3480, 'for last 250 steps:', 0.3639061689376831)
# ('Average loss at step', 3520, 'for last 250 steps:', 0.36161972761154176)
# ('Average loss at step', 3560, 'for last 250 steps:', 0.3657794725894928)
# ('Average loss at step', 3600, 'for last 250 steps:', 0.3604241275787354)
# ('Average loss at step', 3640, 'for last 250 steps:', 0.3628757232427597)
# ('Average loss at step', 3680, 'for last 250 steps:', 0.36457267820835115)
# ('Average loss at step', 3720, 'for last 250 steps:', 0.364504788517952)
# ('Average loss at step', 3760, 'for last 250 steps:', 0.3730140405893326)
# ('Average loss at step', 3800, 'for last 250 steps:', 0.36813152134418486)
# ('Average loss at step', 3840, 'for last 250 steps:', 0.36157369196414946)
# ('Average loss at step', 3880, 'for last 250 steps:', 0.36351379096508024)
# ('Average loss at step', 3920, 'for last 250 steps:', 0.358403235077858)
# ('Average loss at step', 3960, 'for last 250 steps:', 0.3628785914182663)
# ('\nEPOCH', 6)
# ('Average loss at step', 40, 'for last 250 steps:', 0.3724205243587494)
# ('Average loss at step', 80, 'for last 250 steps:', 0.36279728412628176)
# ('Average loss at step', 120, 'for last 250 steps:', 0.3534071409702301)
# ('Average loss at step', 160, 'for last 250 steps:', 0.35657508552074435)
# ('Average loss at step', 200, 'for last 250 steps:', 0.361740802526474)
# ('Average loss at step', 240, 'for last 250 steps:', 0.3540374654531479)
# ('Average loss at step', 280, 'for last 250 steps:', 0.36409782648086547)
# ('Average loss at step', 320, 'for last 250 steps:', 0.3647355043888092)
# ('Average loss at step', 360, 'for last 250 steps:', 0.36613939583301547)
# ('Average loss at step', 400, 'for last 250 steps:', 0.366841744184494)
# ('Average loss at step', 440, 'for last 250 steps:', 0.36088015139102936)
# ('Average loss at step', 480, 'for last 250 steps:', 0.35233811795711517)
# ('Average loss at step', 520, 'for last 250 steps:', 0.3595711052417755)
# ('Average loss at step', 560, 'for last 250 steps:', 0.35696139335632326)
# ('Average loss at step', 600, 'for last 250 steps:', 0.3661806434392929)
# ('Average loss at step', 640, 'for last 250 steps:', 0.35564248979091645)
# ('Average loss at step', 680, 'for last 250 steps:', 0.35383667290210724)
# ('Average loss at step', 720, 'for last 250 steps:', 0.3589404594898224)
# ('Average loss at step', 760, 'for last 250 steps:', 0.3655365228652954)
# ('Average loss at step', 800, 'for last 250 steps:', 0.36580533742904664)
# ('Average loss at step', 840, 'for last 250 steps:', 0.3565398693084717)
# ('Average loss at step', 880, 'for last 250 steps:', 0.3534221255779266)
# ('Average loss at step', 920, 'for last 250 steps:', 0.3539800381660461)
# ('Average loss at step', 960, 'for last 250 steps:', 0.36546267807483673)
# ('Average loss at step', 1000, 'for last 250 steps:', 0.364272323846817)
# ('Average loss at step', 1040, 'for last 250 steps:', 0.36296906888484953)
# ('Average loss at step', 1080, 'for last 250 steps:', 0.3565811413526535)
# ('Average loss at step', 1120, 'for last 250 steps:', 0.3593122434616089)
# ('Average loss at step', 1160, 'for last 250 steps:', 0.35930036664009096)
# ('Average loss at step', 1200, 'for last 250 steps:', 0.36611529648303986)
# ('Average loss at step', 1240, 'for last 250 steps:', 0.3597865283489227)
# ('Average loss at step', 1280, 'for last 250 steps:', 0.36625456392765043)
# ('Average loss at step', 1320, 'for last 250 steps:', 0.3612967765331268)
# ('Average loss at step', 1360, 'for last 250 steps:', 0.35927712976932524)
# ('Average loss at step', 1400, 'for last 250 steps:', 0.36144093453884124)
# ('Average loss at step', 1440, 'for last 250 steps:', 0.35882825195789336)
# ('Average loss at step', 1480, 'for last 250 steps:', 0.3609035491943359)
# ('Average loss at step', 1520, 'for last 250 steps:', 0.36329858541488647)
# ('Average loss at step', 1560, 'for last 250 steps:', 0.3664789414405823)
# ('Average loss at step', 1600, 'for last 250 steps:', 0.36432624340057373)
# ('Average loss at step', 1640, 'for last 250 steps:', 0.3633380562067032)
# ('Average loss at step', 1680, 'for last 250 steps:', 0.3524251466989517)
# ('Average loss at step', 1720, 'for last 250 steps:', 0.35392642140388486)
# ('Average loss at step', 1760, 'for last 250 steps:', 0.364609951376915)
# ('Average loss at step', 1800, 'for last 250 steps:', 0.3592729914188385)
# ('Average loss at step', 1840, 'for last 250 steps:', 0.3559000682830811)
# ('Average loss at step', 1880, 'for last 250 steps:', 0.363665012717247)
# ('Average loss at step', 1920, 'for last 250 steps:', 0.35811766743659973)
# ('Average loss at step', 1960, 'for last 250 steps:', 0.36318301379680634)
# ('Average loss at step', 2000, 'for last 250 steps:', 0.3545024400949478)
# ('Average loss at step', 2040, 'for last 250 steps:', 0.3675456362962723)
# ('Average loss at step', 2080, 'for last 250 steps:', 0.3561729681491852)
# ...
# ('Average loss at step', 3880, 'for last 250 steps:', 0.3556519305706024)
# ('Average loss at step', 3920, 'for last 250 steps:', 0.3603820925951004)
# ('Average loss at step', 3960, 'for last 250 steps:', 0.36237909853458405)
# ('\nEPOCH', 8)
# ('Average loss at step', 40, 'for last 250 steps:', 0.3692541038990021)
# ('Average loss at step', 80, 'for last 250 steps:', 0.36384031295776365)
# ('Average loss at step', 120, 'for last 250 steps:', 0.36652364015579225)
# ('Average loss at step', 160, 'for last 250 steps:', 0.3521962529420853)
# ('Average loss at step', 200, 'for last 250 steps:', 0.35270713686943056)
# ('Average loss at step', 240, 'for last 250 steps:', 0.3622143346071243)
# ('Average loss at step', 280, 'for last 250 steps:', 0.35304160714149474)
# ('Average loss at step', 320, 'for last 250 steps:', 0.3625794631242752)
# ('Average loss at step', 360, 'for last 250 steps:', 0.3544038850069046)
# ('Average loss at step', 400, 'for last 250 steps:', 0.3538655513525009)
# ('Average loss at step', 440, 'for last 250 steps:', 0.3618646389245987)
# ('Average loss at step', 480, 'for last 250 steps:', 0.3565188843011856)
# ('Average loss at step', 520, 'for last 250 steps:', 0.35729890763759614)
# ('Average loss at step', 560, 'for last 250 steps:', 0.36481560826301573)
# ('Average loss at step', 600, 'for last 250 steps:', 0.3543188232183456)
# ('Average loss at step', 640, 'for last 250 steps:', 0.35441522538661957)
# ('Average loss at step', 680, 'for last 250 steps:', 0.3665034639835358)
# ('Average loss at step', 720, 'for last 250 steps:', 0.3620456874370575)
# ('Average loss at step', 760, 'for last 250 steps:', 0.35686164259910585)
# ('Average loss at step', 800, 'for last 250 steps:', 0.3549081069231033)
# ('Average loss at step', 840, 'for last 250 steps:', 0.3500709807872772)
# ('Average loss at step', 880, 'for last 250 steps:', 0.3593739867210388)
# ('Average loss at step', 920, 'for last 250 steps:', 0.35794829308986664)
# ('Average loss at step', 960, 'for last 250 steps:', 0.3561595004796982)
# ('Average loss at step', 1000, 'for last 250 steps:', 0.35282171368598936)
# ('Average loss at step', 1040, 'for last 250 steps:', 0.3506320470571518)
# ('Average loss at step', 1080, 'for last 250 steps:', 0.362991943359375)
# ('Average loss at step', 1120, 'for last 250 steps:', 0.3638933378458023)
# ('Average loss at step', 1160, 'for last 250 steps:', 0.3581396424770355)
# ('Average loss at step', 1200, 'for last 250 steps:', 0.35495687067508697)
# ('Average loss at step', 1240, 'for last 250 steps:', 0.36557836055755616)
# ('Average loss at step', 1280, 'for last 250 steps:', 0.3529182654619217)
# ('Average loss at step', 1320, 'for last 250 steps:', 0.35802082359790804)
# ('Average loss at step', 1360, 'for last 250 steps:', 0.3591440755128861)
# ('Average loss at step', 1400, 'for last 250 steps:', 0.3625487381219864)
# ('Average loss at step', 1440, 'for last 250 steps:', 0.3573386025428772)
# ('Average loss at step', 1480, 'for last 250 steps:', 0.35569690227508544)
# ('Average loss at step', 1520, 'for last 250 steps:', 0.3691102778911591)
# ('Average loss at step', 1560, 'for last 250 steps:', 0.3542125689983368)
# ('Average loss at step', 1600, 'for last 250 steps:', 0.3629653114080429)
# ('Average loss at step', 1640, 'for last 250 steps:', 0.3569196403026581)
# ('Average loss at step', 1680, 'for last 250 steps:', 0.35166229009628297)
# ('Average loss at step', 1720, 'for last 250 steps:', 0.36038682103157044)
# ('Average loss at step', 1760, 'for last 250 steps:', 0.35553198456764223)
# ('Average loss at step', 1800, 'for last 250 steps:', 0.35947565615177157)
# ('Average loss at step', 1840, 'for last 250 steps:', 0.3620257967710495)
# ('Average loss at step', 1880, 'for last 250 steps:', 0.35207482099533083)
# ('Average loss at step', 1920, 'for last 250 steps:', 0.3583634656667709)
# ('Average loss at step', 1960, 'for last 250 steps:', 0.3556545090675354)
# ('Average loss at step', 2000, 'for last 250 steps:', 0.3561756002902985)
# ('Average loss at step', 2040, 'for last 250 steps:', 0.3552329778671265)
# ('Average loss at step', 2080, 'for last 250 steps:', 0.36194044947624204)
# ('Average loss at step', 2120, 'for last 250 steps:', 0.35225623071193696)
# ('Average loss at step', 2160, 'for last 250 steps:', 0.36236561834812164)
# ('Average loss at step', 2200, 'for last 250 steps:', 0.3575194346904755)
# ('Average loss at step', 2240, 'for last 250 steps:', 0.3629414337873459)
# ('Average loss at step', 2280, 'for last 250 steps:', 0.3499203646183014)
# ('Average loss at step', 2320, 'for last 250 steps:', 0.3506327509880066)
# ('Average loss at step', 2360, 'for last 250 steps:', 0.3567656123638153)
# ('Average loss at step', 2400, 'for last 250 steps:', 0.3604027140140533)
# ('Average loss at step', 2440, 'for last 250 steps:', 0.35452782452106474)
# ('Average loss at step', 2480, 'for last 250 steps:', 0.35832683980464936)
# ('Average loss at step', 2520, 'for last 250 steps:', 0.3555182808637619)
# ('Average loss at step', 2560, 'for last 250 steps:', 0.3513267207145691)
# ('Average loss at step', 2600, 'for last 250 steps:', 0.3510856634378433)
# ('Average loss at step', 2640, 'for last 250 steps:', 0.36266290843486787)
# ('Average loss at step', 2680, 'for last 250 steps:', 0.35302991688251495)
# ('Average loss at step', 2720, 'for last 250 steps:', 0.35983827352523806)
# ('Average loss at step', 2760, 'for last 250 steps:', 0.36514456272125245)
# ('Average loss at step', 2800, 'for last 250 steps:', 0.3592937982082367)
# ('Average loss at step', 2840, 'for last 250 steps:', 0.35673325896263125)
# ('Average loss at step', 2880, 'for last 250 steps:', 0.3515580302476883)
# ('Average loss at step', 2920, 'for last 250 steps:', 0.3519788944721222)
# ('Average loss at step', 2960, 'for last 250 steps:', 0.35833744406700135)
# ('Average loss at step', 3000, 'for last 250 steps:', 0.3705005842447281)
# ('Average loss at step', 3040, 'for last 250 steps:', 0.34654693484306337)
# ('Average loss at step', 3080, 'for last 250 steps:', 0.3556629210710526)
# ('Average loss at step', 3120, 'for last 250 steps:', 0.3622913736104965)
# ('Average loss at step', 3160, 'for last 250 steps:', 0.36574917793273926)
# ('Average loss at step', 3200, 'for last 250 steps:', 0.3620319759845734)
# ('Average loss at step', 3240, 'for last 250 steps:', 0.3588095164299011)
# ('Average loss at step', 3280, 'for last 250 steps:', 0.3632337898015976)
# ('Average loss at step', 3320, 'for last 250 steps:', 0.3579855525493622)
# ('Average loss at step', 3360, 'for last 250 steps:', 0.3601683861017227)
# ('Average loss at step', 3400, 'for last 250 steps:', 0.3643999034166336)
# ('Average loss at step', 3440, 'for last 250 steps:', 0.366184298992157)
# ('Average loss at step', 3480, 'for last 250 steps:', 0.3582110691070557)
# ('Average loss at step', 3520, 'for last 250 steps:', 0.36340559720993043)
# ('Average loss at step', 3560, 'for last 250 steps:', 0.36306315183639526)
# ('Average loss at step', 3600, 'for last 250 steps:', 0.3587863004207611)
# ('Average loss at step', 3640, 'for last 250 steps:', 0.3597585153579712)
# ('Average loss at step', 3680, 'for last 250 steps:', 0.35758164823055266)
# ('Average loss at step', 3720, 'for last 250 steps:', 0.3591075474023819)
# ('Average loss at step', 3760, 'for last 250 steps:', 0.3515399622917175)
# ('Average loss at step', 3800, 'for last 250 steps:', 0.3632860106229782)
# ('Average loss at step', 3840, 'for last 250 steps:', 0.3587202775478363)
# ('Average loss at step', 3880, 'for last 250 steps:', 0.3652341139316559)
# ('Average loss at step', 3920, 'for last 250 steps:', 0.3656222862005234)
# ('Average loss at step', 3960, 'for last 250 steps:', 0.3540211409330368)
# ('\nEPOCH', 9)
# ('Average loss at step', 40, 'for last 250 steps:', 0.3645041459798813)
# ('Average loss at step', 80, 'for last 250 steps:', 0.3628292775154114)
# ('Average loss at step', 120, 'for last 250 steps:', 0.36152250111103057)
# ('Average loss at step', 160, 'for last 250 steps:', 0.36105055272579195)
# ('Average loss at step', 200, 'for last 250 steps:', 0.3661315876245499)
# ('Average loss at step', 240, 'for last 250 steps:', 0.36321927189826964)
# ('Average loss at step', 280, 'for last 250 steps:', 0.35631898522377015)
# ('Average loss at step', 320, 'for last 250 steps:', 0.36103091180324554)
# ('Average loss at step', 360, 'for last 250 steps:', 0.36239482045173643)
# ('Average loss at step', 400, 'for last 250 steps:', 0.3533842325210571)
# ('Average loss at step', 440, 'for last 250 steps:', 0.36113003551959993)
# ('Average loss at step', 480, 'for last 250 steps:', 0.36447892904281615)
# ('Average loss at step', 520, 'for last 250 steps:', 0.3499512803554535)
# ('Average loss at step', 560, 'for last 250 steps:', 0.3601254200935364)
# ('Average loss at step', 600, 'for last 250 steps:', 0.361429962515831)
# ('Average loss at step', 640, 'for last 250 steps:', 0.35697173595428466)
# ('Average loss at step', 680, 'for last 250 steps:', 0.35980661273002623)
# ('Average loss at step', 720, 'for last 250 steps:', 0.3562218064069748)
# ('Average loss at step', 760, 'for last 250 steps:', 0.36112141847610474)
# ('Average loss at step', 800, 'for last 250 steps:', 0.35883083164691926)
# ('Average loss at step', 840, 'for last 250 steps:', 0.35539633154869077)
# ('Average loss at step', 880, 'for last 250 steps:', 0.36350991785526277)
# ('Average loss at step', 920, 'for last 250 steps:', 0.35656950652599334)
# ('Average loss at step', 960, 'for last 250 steps:', 0.36203585386276244)
# ('Average loss at step', 1000, 'for last 250 steps:', 0.3572743278741837)
# ('Average loss at step', 1040, 'for last 250 steps:', 0.3588973045349121)
# ('Average loss at step', 1080, 'for last 250 steps:', 0.35367916882038114)
# ('Average loss at step', 1120, 'for last 250 steps:', 0.3590926307439804)
# ('Average loss at step', 1160, 'for last 250 steps:', 0.35623164772987365)
# ('Average loss at step', 1200, 'for last 250 steps:', 0.3599440515041351)
# ('Average loss at step', 1240, 'for last 250 steps:', 0.352794851064682)
# ('Average loss at step', 1280, 'for last 250 steps:', 0.35456388831138613)
# ('Average loss at step', 1320, 'for last 250 steps:', 0.36130730926990506)
# ('Average loss at step', 1360, 'for last 250 steps:', 0.35362924218177794)
# ('Average loss at step', 1400, 'for last 250 steps:', 0.35316726565361023)
# ('Average loss at step', 1440, 'for last 250 steps:', 0.3627156275510788)
# ('Average loss at step', 1480, 'for last 250 steps:', 0.3536292266845703)
# ('Average loss at step', 1520, 'for last 250 steps:', 0.3585195344686508)
# ('Average loss at step', 1560, 'for last 250 steps:', 0.3531322360038757)
# ('Average loss at step', 1600, 'for last 250 steps:', 0.3537535178661346)
# ('Average loss at step', 1640, 'for last 250 steps:', 0.3628803539276123)
# ('Average loss at step', 1680, 'for last 250 steps:', 0.36280183792114257)
# ('Average loss at step', 1720, 'for last 250 steps:', 0.3555470162630081)
# ('Average loss at step', 1760, 'for last 250 steps:', 0.36308923065662385)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-a1b491b3d9db> in <module>()
# ----> 1 training_losses = train_network(10,num_steps, state_size)
#       2 plt.plot(training_losses)
#
# <ipython-input-10-c9efa3e1b10f> in train_network(num_epochs, num_steps, state_size, verbose)
#      18                               train_step,
#      19                               predictions],
# ---> 20                                   feed_dict={x:X, y:Y, init_state:training_state})
#      21                 training_loss += training_loss_
#      22
#
# /Users/bm255022/virtualenvs/tensorflow27/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in run(self, fetches, feed_dict, options, run_metadata)
#     903     try:
#     904       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 905                          run_metadata_ptr)
#     906       if run_metadata:
#     907         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /Users/bm255022/virtualenvs/tensorflow27/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1123     # Create a fetch handler to take care of the structure of fetches.
#    1124     fetch_handler = _FetchHandler(
# -> 1125         self._graph, fetches, feed_dict_tensor, feed_handles=feed_handles)
#    1126
#    1127     # Run request and get response.
#
# /Users/bm255022/virtualenvs/tensorflow27/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in __init__(self, graph, fetches, feeds, feed_handles)
#     425     """
#     426     with graph.as_default():
# --> 427       self._fetch_mapper = _FetchMapper.for_fetch(fetches)
#     428     self._fetches = []
#     429     self._targets = []
#
# /Users/bm255022/virtualenvs/tensorflow27/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in for_fetch(fetch)
#     243     elif isinstance(fetch, (list, tuple)):
#     244       # NOTE(touts): This is also the code path for namedtuples.
# --> 245       return _ListFetchMapper(fetch)
#     246     elif isinstance(fetch, dict):
#     247       return _DictFetchMapper(fetch)
#
# /Users/bm255022/virtualenvs/tensorflow27/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in __init__(self, fetches)
#     350     """
#     351     self._fetch_type = type(fetches)
# --> 352     self._mappers = [_FetchMapper.for_fetch(fetch) for fetch in fetches]
#     353     self._unique_fetches, self._value_indices = _uniquify_fetches(self._mappers)
#     354
#
# /Users/bm255022/virtualenvs/tensorflow27/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in for_fetch(fetch)
#     243     elif isinstance(fetch, (list, tuple)):
#     244       # NOTE(touts): This is also the code path for namedtuples.
# --> 245       return _ListFetchMapper(fetch)
#     246     elif isinstance(fetch, dict):
#     247       return _DictFetchMapper(fetch)
#
# /Users/bm255022/virtualenvs/tensorflow27/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in __init__(self, fetches)
#     350     """
#     351     self._fetch_type = type(fetches)
# --> 352     self._mappers = [_FetchMapper.for_fetch(fetch) for fetch in fetches]
#     353     self._unique_fetches, self._value_indices = _uniquify_fetches(self._mappers)
#     354
#
# /Users/bm255022/virtualenvs/tensorflow27/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in for_fetch(fetch)
#     251         if isinstance(fetch, tensor_type):
#     252           fetches, contraction_fn = fetch_fn(fetch)
# --> 253           return _ElementFetchMapper(fetches, contraction_fn)
#     254     # Did not find anything.
#     255     raise TypeError('Fetch argument %r has invalid type %r' % (fetch,
#
# /Users/bm255022/virtualenvs/tensorflow27/lib/python2.7/site-packages/tensorflow/python/client/session.pyc in __init__(self, fetches, contraction_fn)
#     279     for fetch in fetches:
#     280       try:
# --> 281         self._unique_fetches.append(ops.get_default_graph().as_graph_element(
#     282             fetch, allow_tensor=True, allow_operation=True))
#     283       except TypeError as e:
#
# /Users/bm255022/virtualenvs/tensorflow27/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in get_default_graph()
#    5331     The default `Graph` being used in the current thread.
#    5332   """
# -> 5333   return _default_graph_stack.get_default()
#    5334
#    5335
#
# /Users/bm255022/virtualenvs/tensorflow27/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in get_default(self)
#    5061   def get_default(self):
#    5062     """Override that returns a global default if the stack is empty."""
# -> 5063     ret = super(_DefaultGraphStack, self).get_default()
#    5064     if ret is None:
#    5065       ret = self._GetGlobalDefaultGraph()
#
# /Users/bm255022/virtualenvs/tensorflow27/lib/python2.7/site-packages/tensorflow/python/framework/ops.pyc in get_default(self)
#    4873
#    4874   def get_default(self):
# -> 4875     return self.stack[-1] if len(self.stack) >= 1 else None
#    4876
#    4877   def reset(self):
#
# KeyboardInterrupt:
